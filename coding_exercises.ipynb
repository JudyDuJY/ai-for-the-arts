# %% [markdown]
# #Coding Practice Notebook
# This notebook is used to explore and practice basic programming concepts using Python.
# It documented my learning process through examples, experiments, and reflections
# Support for artificial intelligence tools such as Microsoft Copilot.
# ##Goal
# -Learn how to read and understand simple Python code
# -Practice using Jupyter Notebook with code and markdown cells
# -Run and modify the example program, such as "Hello, World
# -Understand key programming concepts (variables, functions, loops, and data types)
# -Reflecting on how programming and artificial intelligence are associated with artistic and humanistic backgrounds

# %% [markdown]
# ##Hello, world!
# The following code was created when I first attempted programming in this course.
# It aims to help me understand how to write and run Python code in GitHub Codespace,
# Familiar with using code cells and markdown cells in Jupyter Notebook.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %% [markdown]
# Submit the following prompt to Copilot: “Could you suggest a python
# code for ‘Hello, world!’ to demonstrate the concept of printing to a
# complete beginner in programming? Please explain the code step-by-step
# highlighting any key aspects. ”
# I have learned in detail the functions of different characters and how to use strings and function calls.

# %%
print("Hello, world!")
# Out:
# Hello, world!

# %%
print("Hello,", "world!")  # prints: Hello, world!
# Out:
# Hello, world!

# %% [markdown]
# # 1.Concept: Variables
# **Copilot initial prompt:**
# Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of variables to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects.
# **Follow-up prompts (if any)**
# “Give me examples”
# ## My notes
# Learn the basic usage of variables, such as message（ String) exclamation_count（ Integer). Master the usage of "message=" (storing values in names) and "Reassignment" (variables can be changed at any time).
# ## The code I tested

# %%
# 1) Create a variable and store text in it
message = "Hello, world!"

# 2) Print the value stored in the variable
print(message)

# 3) Change the variable's value
message = "Hello, Python learner!"

# 4) Use another variable to keep track of a number
exclamation_count = 3

# 5) Combine text and a number using an f-string
print(f"{message} " + "!" * exclamation_count)
# Out:
# Hello, world!
# Hello, Python learner! !!!

# %% [markdown]
# # 2.Concept:Functions
# **Copilot initial prompt:**
# Could you suggest a modification of the Python code for “Hello,
# world!” to demonstrate the concept of functions to a complete beginner in
# programming? Please explain the code step-by-step highlighting any key
# aspects.
# **Follow-up prompts(if any)**
# “Modify make_greeting, Add 'Good morning' greeting.”
# ## My notes
# I learned how to use the ‘def’ keyword, which is short for "define," meaning "define a function." Parameters represent the information needed by the function, while arguments represent the actual values ​​passed when calling the function. I also learned about ‘return’， which ends the function and returns the result to the caller.
# ## The code I tested

# %%
def say_hello():
    print("Hello, world!")

# Call (run) the function
say_hello()
# Out:
# Hello, world!

# %%
def greet(name):
    print("Hello, " + name + "!")

greet("Alice")
greet("world")  # still works like Hello, world!
# Out:
# Hello, Alice!
# Hello, world!

# %% [markdown]
# # 3.Concept:Loops
# **Copilot initial prompt:**
# Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of loops to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects.
# ## My notes
# I learned that indentation determines the content of a loop (Python doesn't use {}). I also learned about for loops (suitable for loops with a known number of repetitions), while loops (suitable for loops based on a condition), and how to avoid infinite loops (ensuring the condition changes).
# ## The code I tested

# %%
# Print "Hello, world!" five times using a for loop

for i in range(5):
    print("Hello, world!")
# Out:
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!

# %%
# Number each greeting, starting from 1

for i in range(5):
    print(f"{i + 1}. Hello, world!")
# Out:
# 1. Hello, world!
# 2. Hello, world!
# 3. Hello, world!
# 4. Hello, world!
# 5. Hello, world!

# %%
# Print "Hello, world!" five times using a while loop

count = 0                 # 1) initialize a counter
while count < 5:          # 2) loop condition checked before each iteration
    print("Hello, world!")
    count = count + 1     # 3) update the counter (could also write: count += 1)
# Out:
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!
# Hello, world!

# %% [markdown]
# # 4.Concept: data structures such as lists
# **Copilot initial prompt:**
# Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of lists to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects.
# ## My notes
# In the list, items are separated by commas. And the indexing starts from 0 (messages[0] is the first item). I also learned about the mutability of lists, such as appending to add items. Furthermore, len(list) can get the number of items.
# ## The code I tested

# %%
# 1) Create a list of messages (strings)
messages = ["Hello, world!", "Hi there!", "Welcome to Python!"]

# 2) Print the first message
print(messages[0])  # Index 0 refers to the first item

# 3) Add (append) a new message to the list
messages.append("Lists are fun!")

# 4) Print how many items are in the list
print("Number of messages:", len(messages))

# 5) Print every message, one per line (loop through the list)
for msg in messages:
    print(msg)
# Out:
# Hello, world!
# Number of messages: 4
# Hello, world!
# Hi there!
# Welcome to Python!
# Lists are fun!

# %%
# 1) Create a list of messages (strings)
messages = ["Hello, world!", "Hi there!", "Welcome to Python!"]

# 2) Print the first message
print(messages[1])  # Index 0 refers to the first item

# 3) Add (append) a new message to the list
messages[2] = "Learning lists is easy!"

# 4) Print how many items are in the list
print("Number of messages:", len(messages))

# 5) Print every message, one per line (loop through the list)
for msg in messages:
    print(msg)
# Out:
# Hi there!
# Number of messages: 3
# Hello, world!
# Hi there!
# Learning lists is easy!

# %% [markdown]
# # 5.Concept: data structures such as dictionaries
# **Copilot initial prompt:**
# Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of dictionaries to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects.
# **Follow-up prompts(if any)**
# “Add an interactive version of input() to my project.”
# ## My notes
# A dictionary is a key-value collection enclosed in curly braces {}, where keys are usually strings and must be immutable. There are two ways to access it: one is [key] (which will throw an error if the key does not exist), and the other is .get(key, default value) (safe).
# ## The code I tested

# %%
# 1) Define a dictionary that maps language names (keys) to a greeting (value)
greetings = {
    "English": "Hello, world!",
    "Chinese": "你好，世界！",
    "Spanish": "¡Hola, mundo!",
    "French": "Bonjour, le monde!",
}

# 2) Pick a language we want to use
chosen_language = "Chinese"

# 3) Look up the greeting by key and print it
print(greetings[chosen_language])

# 4) Add a new key–value pair to the dictionary
greetings["German"] = "Hallo, Welt!"

# 5) Safely get a greeting for a language that may not exist (returns default if missing)
print(greetings.get("Japanese", "Sorry, that language is not available."))

# 6) Update an existing value
greetings["English"] = "Hello, Python world!"

# 7) Loop through the dictionary and print all greetings (key and value)
for language, message in greetings.items():
    print(f"{language}: {message}")
# Out:
# 你好，世界！
# Sorry, that language is not available.
# English: Hello, Python world!
# Chinese: 你好，世界！
# Spanish: ¡Hola, mundo!
# French: Bonjour, le monde!
# German: Hallo, Welt!

# %% [markdown]
# # 6.Concept:  data structures such as arrays
# **Copilot initial prompt:**
# Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of arrays to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects.
# **Follow-up prompts(if any)**
# “Removing and inserting items”
# ## My notes
# Arrays and lists differ. Arrays require all elements to be of the same type, which is more stringent. They also allow for chained numerical calculations, making them more efficient. Therefore, arrays are often used for numerical processing.
# ## The code I tested

# %%
import array

# 1) Create an integer array (typecode 'i' means integer)
numbers = array.array('i', [1, 2, 3, 4, 5])
print(numbers)  # array('i', [1, 2, 3, 4, 5])

# 2) Insert an element
numbers.insert(2, 99)  # Insert 99 at index 2
print(numbers)  # array('i', [1, 2, 99, 3, 4, 5])

# 3) Remove an element by value
numbers.remove(3)  # Remove the element with value 3
print(numbers)  # array('i', [1, 2, 99, 4, 5])

# 4) Use pop to remove and return an element
removed = numbers.pop()  # Remove the last element
print("Removed element:", removed)
print(numbers)

# 5) Iterate through the array
for num in numbers:
    print(num)

# 6) Get the length of the array
print("Array length:", len(numbers))
# Out:
# array('i', [1, 2, 3, 4, 5])
# array('i', [1, 2, 99, 3, 4, 5])
# array('i', [1, 2, 99, 4, 5])
# Removed element: 5
# array('i', [1, 2, 99, 4])
# 1
# 2
# 99
# 4
# Array length: 4

# %% [markdown]
# # 7.Concept:   how to import libraries that extend functionality
# **Copilot initial prompt:**
# Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of importing libraries to a complete beginner in programming? Please explain the code step-by-step highlighting anykey aspects.
# ## My notes
# Importing libraries allows you to reuse existing functionality instead of rewriting it yourself. Standard libraries (such as ‘math’, ‘random’, and ‘datetime’) are installed with Python. Importing methods include: ‘import module’, calling functions using ‘module.function， ‘from module import name’ (directly calling the function), and ‘from module import name as alias’ (giving functions or constants an alias).
# ## The code I tested

# %%
# 1) Basic print to start
print("Hello, world!")

# 2) Import the standard 'math' library and use it
import math
print("Square root of 16 is:", math.sqrt(16))  # 4.0

# 3) Import a specific function from a library
from random import randint
print("A random number between 1 and 10:", randint(1, 10))

# 4) Import with an alias (shorter name)
import datetime as dt
now = dt.datetime.now()
print("Current date and time:", now)

# 5) Using 'from ... import ... as ...' for aliasing a function
from math import pi as PI
print("Value of PI is:", PI)
# Out:
# Hello, world!
# Square root of 16 is: 4.0
# A random number between 1 and 10: 3
# Current date and time: 2025-12-17 02:52:27.637422
# Value of PI is: 3.141592653589793

# %% [markdown]
# # 8. Concept: how to use conditional if, else, elif statements
# **Copilot initial prompt:**
# Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concepts of if, elif, and else statements to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects.
# ## My notes
# The ‘f’statement checks if a condition is true; it executes the statement if the condition is true. ‘Elif’ stands for "otherwise if," meaning it only checks if the preceding condition is false, and multiple ‘elif’ branches are allowed. When all conditions are false, the ‘else’ statement will be true.
# ## The code I tested

# %%
# Hello with mood-based messages using if / elif / else

print("Hello, world!")  # Classic greeting

# Ask the user for their mood
mood = input("How are you feeling today? (happy, sad, tired, or anything else): ")

# Decide what to say based on the mood
if mood == "happy":
    print("That's great! Keep smiling 😊")
elif mood == "sad":
    print("I’m here for you. Tomorrow can be better 💛")
elif mood == "tired":
    print("Take a break and rest. You deserve it 😴")
else:
    print("Thanks for sharing. Wishing you a good day ahead!")
# Out:
# Hello, world!
# That's great! Keep smiling 😊

# %% [markdown]
# # 9. Concept: how to use operators in Python
# **Copilot initial prompt:**
# Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of operators to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects. Include discussions about addition and multiplication between strings and numbers.
# ## My notes
# Different numeric operators allow you to combine different elements or repeat the same elements. Basic numeric operators include: +, -, *, / (floating-point division, keeping decimals), // (integer division, removing decimals), % (remainder), and ** (exponentiation). In string operations, + concatenates strings, and * repeats strings. The operator precedence is multiplication and division first, then addition and subtraction; parentheses take precedence.
# ## The code I tested

# %%
# 9. Operators — starting from "Hello, world!"

# 1) Start with the classic
print("Hello, world!")

# 2) Arithmetic operators with numbers
a = 10
b = 3
print("a + b =", a + b)    # addition
print("a - b =", a - b)    # subtraction
print("a * b =", a * b)    # multiplication
print("a / b =", a / b)    # true division (float)
print("a // b =", a // b)  # floor division (integer result)
print("a % b =", a % b)    # modulus (remainder)
print("a ** b =", a ** b)  # exponentiation

# 3) String operators: + and *
greeting = "Hello"
name = "world"
print(greeting + ", " + name + "!")  # string concatenation with +

echo = "ha"
print(echo * 3)  # string repetition: "hahaha"

# 4) Addition/multiplication between strings and numbers
num = 5
text = "5"

# Valid: number + number
print("num + 5 =", num + 5)

# ❗Invalid: string + number (TypeError)
# print(text + 5)  # Uncommenting this line causes TypeError

# Valid: string + string
print('"5" + "5" =', text + text)

# Valid: string * number (repetition)
print('"hi" * 4 =', "hi" * 4)

# ❗Invalid: number * string * string (only str * int is allowed; order (int * str) is fine too)
# print(3 * "hi" * "bye")  # TypeError

# 5) Comparison operators (return True/False)
print("a == b:", a == b)
print("a != b:", a != b)
print("a > b:", a > b)
print("a <= b:", a <= b)

# 6) Logical operators with booleans
is_big = a > 5
is_small = b < 2
print("is_big and is_small:", is_big and is_small)
print("is_big or is_small:", is_big or is_small)
print("not is_small:", not is_small)

# 7) Assignment operators (shorthand updates)
x = 2
x += 3   # x = x + 3
x *= 4   # x = x * 4
print("x after += and *= is", x)

# 8) Operator precedence (PEMDAS-like; use parentheses to be clear)
print("3 + 2 * 5 =", 3 + 2 * 5)       # multiplication before addition -> 13
print("(3 + 2) * 5 =", (3 + 2) * 5)   # parentheses first -> 25
# Out:
# Hello, world!
# a + b = 13
# a - b = 7
# a * b = 30
# a / b = 3.3333333333333335
# a // b = 3
# a % b = 1
# a ** b = 1000
# Hello, world!
# hahaha
# num + 5 = 10
# "5" + "5" = 55
# "hi" * 4 = hihihihi
# a == b: False
# a != b: True
# a > b: True
# a <= b: False
# is_big and is_small: False
# is_big or is_small: True
# not is_small: True
# x after += and *= is 20
# 3 + 2 * 5 = 13
# (3 + 2) * 5 = 25

# %% [markdown]
# # 10. Concept: how to use advanced concepts such as classes, objects, and methods
# **Copilot initial prompt:**
# Could you suggest a modification of the Python code for “Hello, world!” to demonstrate the concept of classes, objects and methods to a complete beginner in programming? Please explain the code step-by-step highlighting any key aspects.
# ## My notes
# A class, like a blueprint or recipe, defines the structure and behavior of objects. An object (or instance) is a concrete thing created according to the blueprint. A method is a function within a class that represents an action that an object can perform. Within a method, ‘self’ refers to the current object. The difference between properties and methods is that properties are data (e.g., ‘self.name’), while methods are behaviors (e.g., ‘greet()’).
# ## The code I tested

# %%
# 1) Define a class named Greeter
class Greeter:
    # 2) The constructor method: runs when you create a Greeter
    def __init__(self, name="world"):
        # 3) Store data in the object (an attribute)
        self.name = name

    # 4) A method: what the object can do
    def greet(self):
        print(f"Hello, {self.name}!")

    # 5) Another method to change the object's data
    def set_name(self, new_name):
        self.name = new_name

# -------- Using the class (creating objects) --------

# 6) Create a Greeter object (an instance of the class)
g = Greeter()           # uses the default name "world"
g.greet()               # Output: Hello, world!

# 7) Create another object with a custom name
g2 = Greeter("Alice")
g2.greet()              # Output: Hello, Alice!

# 8) Change the name of the first object and greet again
g.set_name("Python")
g.greet()               # Output: Hello, Python!
# Out:
# Hello, world!
# Hello, Alice!
# Hello, Python!

# %% [markdown]
# # 11. Concept: basic Python syntax
# **Copilot initial prompt:**
# Could you use the examples you have provided above to explain basic syntax of Python to a complete beginner in programming? Please explain step-by-step highlighting any key aspects. Please include well known references to Python styling guides.
# Most of that has already been covered in detail above. Below are some other points.
# ## Comments and Docstrings
# Comments should explain why this was done, rather than what was done (the code itself should clearly state "what was done"). Docstrings should use triple quotes, be concise, and begin with a single sentence as a summary. Teams can adopt a consistent docstring style (such as Google style or NumPy style).
# ## The code I tested

# %%
# This prints a simple greeting
print("Hello, world!")  

def add(a, b):
    """Add two numbers and return the result.

    Args:
        a (int | float): The first number.
        b (int | float): The second number.
    Returns:
        int | float: The sum of a and b.
    """
    return a + b
# Out:
# Hello, world!

# %% [markdown]
# ## Whitespace & Indentation
# Add spaces on both sides of operators, but avoid overusing spaces for alignment in high-priority operations. Additionally, place spaces after commas, and do not include extra spaces within parentheses; for example, use (x, y) instead of (x , y ).
# ## The code I tested

# %%
def calculate_total(a, b, c):
    """Calculate a total using a simple formula."""
    total = a + b * c
    return total


def some_function(first_arg, second_arg, third_arg):
    """Return a tuple of the provided arguments."""
    return (first_arg, second_arg, third_arg)


def main():
    # Recommended spacing (one space on each side of operators)
    a = 2
    b = 3
    c = 4
    total = calculate_total(a, b, c)
    print(f"Total: {total}")

    # When breaking function arguments across lines, use consistent indentation
    result = some_function(
        first_arg="Hello",
        second_arg="World",
        third_arg="!",
    )
    print(f"Result: {result}")

# %% [markdown]
# ## Error Handling
# It can capture specific exception types (such as ZeroDivisionError) to avoid naked except statements. Use try/except only when necessary, and do not "swallow" errors without logging them.
# ## The code I tested

# %%
def safe_divide(a, b):
    """Divide a by b, returning None if b is zero."""
    try:
        return a / b
    except ZeroDivisionError:
        return None

print(safe_divide(10, 0))  # -> None
# Out:
# None

# %% [markdown]
# # 12. Concept: best practice in Python to promote principles of simplicity, security and inclusion
# **Copilot initial prompt:**
# Could you suggest three different Python implementations of the Hello World program to emphasise, respectively, principles of simplicity, security, and inclusion? Please explain step-by-step highlighting any key aspects.
# ## Simplicity
# Simplicity has a single responsibility, with only one line of code and a very clear function. It also provides immediate feedback and can be executed directly in the Python interactive environment or archive. Furthermore, the absence of variables, functions, or import modules reduces the learning curve.
# ## The code I tested

# %%
# hello_simple.py

print("Hello, world!")
# Out:
# Hello, world!

# %% [markdown]
# ## Security
# Even simple programs can demonstrate safe coding practices. First, they avoid dangerous functions and refrain from using `eval`, `exec`, or shell commands to prevent injection attacks. Constants are used to imprint messages, preventing malicious modification. Additionally, `sys.stdout.write()` is used to explicitly specify output, making it predictable.
# ## The code I tested

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
Security-aware Hello World: safe handling of input and output
- Avoid dangerous functions (eval/exec, unescaped shell calls)
- Clean external input (remove control characters, HTML-escape)
- Predictable output (no secrets printed)
- Clear main entry point and exit code
- Principle of least privilege: only reads necessary input (CLI args)
"""

import sys
import argparse
import html
import logging
from typing import Tuple


MESSAGE = "Hello, world!"  # fixed message constant (not user-controlled)


def configure_logging(verbose: bool = False) -> None:
    """
    Configure logging.
    - Default WARNING level (only important messages)
    - --verbose shows DEBUG for learning/debugging
    - Simple format, avoid putting uncleaned user input in structured fields
    """
    level = logging.DEBUG if verbose else logging.WARNING
    logging.basicConfig(
        level=level,
        format="%(levelname)s: %(message)s",
    )


def sanitize_user_text(text: str) -> str:
    """
    Clean user input:
    1) Remove non-printable control characters (avoid terminal/log issues)
    2) HTML-escape (if output is later embedded in HTML or viewed in log UIs)
    Note: This is output-layer defense. For databases/CLI/URLs, use
    the right context-specific escaping or parameterization.
    """
    printable = "".join(ch for ch in text if ch.isprintable())
    escaped = html.escape(printable, quote=True)
    return escaped


def parse_args(argv: list[str]) -> Tuple[str, bool]:
    """
    Parse command-line arguments.
    - Optional suffix appended after the base greeting (sanitized)
    - --verbose toggles detailed logs
    """
    parser = argparse.ArgumentParser(
        prog="hello_secure.py",
        description="A security-aware Hello World with safe input/output handling.",
    )
    parser.add_argument(
        "suffix",
        nargs="*",
        help="(optional) text appended after 'Hello, world!'; will be sanitized.",
    )
    parser.add_argument(
        "--verbose",
        action="store_true",
        help="Show debug logs (for learning).",
    )
    args = parser.parse_args(argv)

    suffix_raw = " ".join(args.suffix) if args.suffix else ""
    verbose = bool(args.verbose)
    return suffix_raw, verbose


def main(argv: list[str]) -> int:
    # Parse args
    suffix_raw, verbose = parse_args(argv)
    configure_logging(verbose)

    logging.debug("Raw suffix from argv: %r", suffix_raw)

    # Sanitize input (prevent control chars, HTML/markup injection)
    suffix_safe = sanitize_user_text(suffix_raw)
    logging.debug("Sanitized suffix: %r", suffix_safe)

    # Compose predictable output
    output = f"{MESSAGE} {suffix_safe}" if suffix_safe else MESSAGE

    # Explicit write and flush for consistent behavior
    sys.stdout.write(output + "\n")
    sys.stdout.flush()

    return 0  # success

# %% [markdown]
# ## Inclusion
# It can automatically detect the language; `locale.getdefaultlocale()` selects the language based on the system environment. `print()` in Python 3 can correctly display Chinese, Arabic, and other languages, and also provides RTL language support. In addition, the `_()` marker can be used to translate strings.
# ## The code I tested

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

"""
Inclusion-first Hello World: Internationalization (i18n) & Unicode-friendly output

Features:
- Respects the user's language (environment variables/system locale), with --lang override
- Uses gettext for translations (locales/<lang>/LC_MESSAGES/messages.mo)
- Graceful fallback to English when translation files are missing
- Built-in fallback translations for demo languages (zh, es, ar)
- Optional: create sample messages.po (--init-locales)
- Optional: compile .po -> .mo using msgfmt (--compile-locales)
- Fully Unicode-friendly (Chinese, Arabic, Emojis, etc.)

Quick usage:
  python3 hello_inclusive_full.py
  python3 hello_inclusive_full.py --lang zh
  python3 hello_inclusive_full.py --init-locales --compile-locales --lang zh
  python3 hello_inclusive_full.py --locales-dir ./locales --domain messages
"""

import argparse
import gettext
import locale
import os
import sys
import subprocess
from pathlib import Path
from typing import Optional, Dict


# Built-in fallback translations (used when .mo files are missing)
FALLBACK_TRANSLATIONS: Dict[str, Dict[str, str]] = {
    "zh": {
        "Hello, world!": "你好，世界！",
    },
    "es": {
        "Hello, world!": "¡Hola, mundo!",
    },
    "ar": {
        "Hello, world!": "مرحبا بالعالم!",
    },
    # You can add more languages, e.g.:
    # "fr": {"Hello, world!": "Bonjour le monde!"},
}


def detect_language(cli_lang: Optional[str] = None) -> str:
    """
    Detect language code by priority:
    1) Command-line --lang (e.g., 'zh', 'es', 'ar')
    2) Environment variables LC_ALL / LANG / LANGUAGE (e.g., 'zh_CN.UTF-8' -> 'zh')
    3) Python locale.getdefaultlocale() / locale.getlocale()
    Fallback: 'en'
    """
    if cli_lang:
        return cli_lang.lower()

    # Check common environment variables first
    for env_var in ("LC_ALL", "LANG", "LANGUAGE"):
        val = os.environ.get(env_var)
        if val:
            code = val.split(".")[0].split("_")[0].lower()
            if code:
                return code

    # Try Python locale detection
    loc = None
    try:
        loc, _ = locale.getdefaultlocale()
    except Exception:
        pass

    if not loc:
        try:
            loc, _ = locale.getlocale()
        except Exception:
            pass

    if loc:
        return loc.split("_")[0].lower()

    return "en"


def setup_i18n(domain: str, locales_dir: Path, lang: str) -> None:
    """
    Configure gettext. If the .mo file for the given language is missing:
      1) Install a no-op translator (English source strings)
      2) If FALLBACK_TRANSLATIONS contains the language, bind a fallback translator to builtins._

    Expected file path:
      locales/<lang>/LC_MESSAGES/<domain>.mo
    """
    try:
        translation = gettext.translation(
            domain=domain,
            localedir=str(locales_dir),
            languages=[lang],
        )
        translation.install()  # install _() into builtins
    except FileNotFoundError:
        # Fall back to English
        gettext.install(domain)
        # If we have a built-in dictionary for the language, override _ with it
        import builtins
        if lang in FALLBACK_TRANSLATIONS:
            translations = FALLBACK_TRANSLATIONS[lang]

            def _fallback(text: str) -> str:
                return translations.get(text, text)

            builtins._ = _fallback  # override _ with our fallback function


def ensure_locales_structure(locales_dir: Path, lang: str) -> None:
    """
    Ensure directory exists: locales/<lang>/LC_MESSAGES
    """
    target = locales_dir / lang / "LC_MESSAGES"
    target.mkdir(parents=True, exist_ok=True)


def write_sample_po(locales_dir: Path, lang: str, domain: str) -> Path:
    """
    Write a sample messages.po (includes only 'Hello, world!' entry)
    Returns the path to the written .po file
    """
    ensure_locales_structure(locales_dir, lang)
    po_path = locales_dir / lang / "LC_MESSAGES" / f"{domain}.po"
    content = (
        'msgid ""\n'
        'msgstr ""\n'
        '"Project-Id-Version: hello-inclusion 1.0\\n"\n'
        '"Content-Type: text/plain; charset=UTF-8\\n"\n'
        f'"Language: {lang}\\n"\n'
        "\n"
        "#: hello_inclusive_full.py\n"
        'msgid "Hello, world!"\n'
        f'msgstr "{FALLBACK_TRANSLATIONS.get(lang, {}).get("Hello, world!", "Hello, world!")}"\n'
    )
    po_path.write_text(content, encoding="utf-8")
    return po_path


def compile_po_to_mo(po_path: Path, mo_path: Path) -> bool:
    """
    Compile .po -> .mo using msgfmt.
    Returns True on success, False on failure (including msgfmt not found).
    """
    try:
        result = subprocess.run(
            ["msgfmt", str(po_path), "-o", str(mo_path)],
            stdout=subprocess.PIPE,
            stderr=subprocess.PIPE,
            text=True,
            check=False,
        )
        return result.returncode == 0
    except FileNotFoundError:
        return False


def init_locales(locales_dir: Path, domain: str, languages: list[str]) -> None:
    """
    Initialize sample .po files for multiple languages based on FALLBACK_TRANSLATIONS.
    """
    for lang in languages:
        po_path = write_sample_po(locales_dir, lang, domain)
        print(f"[init] wrote {po_path}")


def compile_all_locales(locales_dir: Path, domain: str, languages: list[str]) -> None:
    """
    Compile specified languages' .po files into .mo files.
    """
    for lang in languages:
        lc_dir = locales_dir / lang / "LC_MESSAGES"
        po_path = lc_dir / f"{domain}.po"
        mo_path = lc_dir / f"{domain}.mo"
        if not po_path.exists():
            print(f"[compile] skip {lang}: {po_path} not found")
            continue
        ok = compile_po_to_mo(po_path, mo_path)
        if ok:
            print(f"[compile] ok: {mo_path}")
        else:
            print(f"[compile] failed: {po_path} (is 'msgfmt' installed?)")


def parse_args(argv: list[str]) -> argparse.Namespace:
    parser = argparse.ArgumentParser(
        prog="hello_inclusive_full.py",
        description="Inclusion-first Hello World with i18n and Unicode-friendly output.",
    )
    parser.add_argument(
        "--lang",
        help="Force language (e.g., 'en', 'zh', 'es', 'ar'). If omitted, auto-detect.",
    )
    parser.add_argument(
        "--locales-dir",
        default="locales",
        help="Directory containing translation files (default: ./locales).",
    )
    parser.add_argument(
        "--domain",
        default="messages",
        help="gettext domain name (default: 'messages').",
    )
    parser.add_argument(
        "--init-locales",
        action="store_true",
        help="Create sample .po files (based on FALLBACK_TRANSLATIONS).",
    )
    parser.add_argument(
        "--compile-locales",
        action="store_true",
        help="Compile all sample .po -> .mo (requires system 'msgfmt').",
    )
    parser.add_argument(
        "--verbose",
        action="store_true",
        help="Show more detailed execution info.",
    )
    return parser.parse_args(argv)


def main(argv: list[str]) -> int:
    args = parse_args(argv)
    locales_dir = Path(args.locales_dir).resolve()
    domain = args.domain

    # Detect or force language
    lang = detect_language(args.lang)

    # Optional: initialize sample translations (.po)
    if args.init_locales:
        languages = sorted(FALLBACK_TRANSLATIONS.keys())
        init_locales(locales_dir, domain, languages)

    # Optional: compile all (.po -> .mo)
    if args.compile_locales:
        languages = sorted(FALLBACK_TRANSLATIONS.keys())
        compile_all_locales(locales_dir, domain, languages)

    # Set up i18n (if .mo is missing, fall back to English and/or built-in translations)
    setup_i18n(domain=domain, locales_dir=locales_dir, lang=lang)

    # Translatable message
    greeting = _("Hello, world!")

    # Output (Python 3's print is Unicode-friendly)
    if args.verbose:
        print(f"[info] lang={lang}, locales_dir={locales_dir}, domain={domain}")
    print(greeting)

    return 0

# %% [markdown]
# ## Discussion
#
# These code snippets generally function correctly if the relevant prerequisites are executed first. If they fail to execute, it's usually due to the use of undefined variables or functions, incomplete code (e.g., missing parentheses), cells not being executed sequentially in Jupyter Notebook, or indentation errors. Our discussion revealed that the code provided by Copilot is sometimes only for demonstrating the structure and not all can be executed directly; users need to complete or modify it themselves. Although the examples obtained from Copilot by different people may differ in form, they all illustrate the same concept in different ways, such as storing and outputting data through variables, reassigning values, adding user input, or demonstrating different data types. By comparing these examples, we can understand that the same program concept can be presented in multiple ways, and the key to successful program execution lies in whether the code is complete and correct.

# %% [markdown]
# ## Learning Summary
# Through continuously modifying and extending the "Hello, world!" program, I gradually learned the fundamental programming concepts of Python and gained a clearer understanding of Python's basic structure and syntax.
# First, I learned about variables, understanding how to use `=` to store data, the differences between different data types, and how variables can be reassigned during program execution. Next, I learned the basic concepts of functions, including using `def` to define functions, the difference between parameters and arguments, and the purpose of `return` to make code more structured and reusable.
# In the area of ​​loops, I learned about `for` and `while` loops, and how Python uses indentation to determine program blocks, and how to avoid infinite loops. Afterward, I encountered various data structures, including lists, dictionaries, and arrays, and understood their different uses in storing and processing data.
# Furthermore, I learned how to import modules to extend Python's functionality and practiced using conditional statements (if/elif/else) to control program flow. I also gained a basic understanding of operators and their order of precedence.
# Finally, I had an initial introduction to object-oriented programming, learning about the concepts of categories, objects, and methods. I also learned some basic Python coding conventions and best practices, such as indentation, comments, error handling, and program conciseness and security.

# %% [markdown]
# ## Reflections on Learning with Copilot
# In my Python learning process, GitHub Copilot has been a very useful tool. I use clear prompts to guide Copilot through explaining concepts and providing modified examples step-by-step, rather than simply copying code.
# Copilot helps me transform abstract concepts into practical code examples, making it easier to understand the differences between various coding styles. Simultaneously, I test and modify the code, organizing my notes to ensure I truly understand how the program works.
# Overall, Copilot acts as a learning assistant, helping me understand fundamental Python concepts and boosting my confidence in programming.

# %% [markdown]
# ## Working with Algorithms
# ## Everyday-life algorithms I noticed
#
# An algorithm is basically a clear set of steps to reach a goal. When I thought about my daily life, I realised I follow “algorithms” all the time without calling them that.
#
# ### 1) Shopping at a supermarket
# 1. Make a shopping list.
# 2. Go to the store.
# 3. Pick items based on the list.
# 4. Compare prices or brands.
# 5. Go to the checkout.
# 6. Pay and leave the store.
#
# ### 2) Getting ready to leave the house
# 1. Check the time and weather.
# 2. Choose clothes based on weather.
# 3. Pack essentials (phone, keys, wallet, student card).
# 4. Check route / bus times.
# 5. Put on shoes
# 6. Lock the door.
# 7. Leave.
#
# ### 3) Ordering food using a mobile app
# 1. Open the food delivery app.
# 2. Choose a restaurant.
# 3. Browse the menu.
# 4. Add items to the cart.
# 5. Confirm delivery address and payment method.
# 6. Place the order.
# 7. Wait for delivery.
# 8. Receive and eat the food.

# %% [markdown]
# ##Pseudocode
# ##Example 1: Ordering food with an app (pseudocode)
# INPUT: list of restaurants, menu items, user preferences, budget
#
# choose restaurant based on preferences
# create empty list called "cart"
# set total_cost = 0
#
# FOR each item in restaurant menu:
#     IF item matches preferences AND (total_cost + item price) <= budget:
#         add item to cart
#         total_cost = total_cost + item price
#
# IF cart is empty:
#     choose cheapest suitable item
#     add it to cart
#
# confirm address and payment
# place order
#
# OUTPUT: order confirmation + estimated delivery time
#
#
# ##Example 2: Managing a to-do list (pseudocode)
# INPUT: list of tasks
#
# create empty dictionary called "priority_groups"
#
# FOR each task in tasks:
#     read priority of task (high/medium/low)
#     IF priority not in priority_groups:
#         create empty list for that priority in priority_groups
#     add task to priority_groups[priority]
#
# create list called "order" = [high, medium, low]
#
# FOR each p in order:
#     FOR each task in priority_groups[p]:
#         do task
#         mark task as completed
#
# OUTPUT: all tasks completed

# %% [markdown]
# ## Code

# %%
from collections import Counter
import string

# Input poem text (Shakespeare’s Sonnet 18 - excerpt)
poem = """Shall I compare thee to a summer's day?
Thou art more lovely and more temperate:
Rough winds do shake the darling buds of May,
And summer's lease hath all too short a date:"""

# Convert to lowercase
poem = poem.lower()

# Remove punctuation
poem = poem.translate(str.maketrans("", "", string.punctuation))

# Split into words
words = poem.split()

# Count word frequency
counts = Counter(words)

# Find the most common word
most_common = counts.most_common(1)[0]

# Output result
print("Most frequent word:", most_common[0], "appears", most_common[1], "times")
# Out:
# Most frequent word: a appears 2 times

# %% [markdown]
# ## Example 1: Ordering Food with an App

# %%
# ordering_food.py
from dataclasses import dataclass
from typing import List, Dict, Any, Optional


@dataclass
class MenuItem:
    name: str
    price: float
    tags: List[str]


@dataclass
class Restaurant:
    name: str
    menu: List[MenuItem]
    tags: List[str]


def matches_preferences(item: MenuItem, preferences: List[str]) -> bool:
    """Return True if the menu item matches any preference tag."""
    if not preferences:
        return True
    item_tags = {t.lower() for t in item.tags}
    return any(pref.lower() in item_tags for pref in preferences)


def choose_restaurant(restaurants: List[Restaurant], preferences: List[str]) -> Optional[Restaurant]:
    """Choose the best restaurant based on how many preference tags it matches."""
    if not restaurants:
        return None

    prefs = [p.lower() for p in preferences]

    def score(r: Restaurant) -> int:
        r_tags = {t.lower() for t in r.tags}
        return sum(1 for p in prefs if p in r_tags)

    # pick the restaurant with the highest score (ties: first one)
    return max(restaurants, key=score)


def build_cart(restaurant: Restaurant, preferences: List[str], budget: float) -> List[MenuItem]:
    """Build a cart under budget. If nothing fits, pick the cheapest suitable item."""
    cart: List[MenuItem] = []
    total_cost = 0.0

    for item in restaurant.menu:
        if matches_preferences(item, preferences) and (total_cost + item.price) <= budget:
            cart.append(item)
            total_cost += item.price

    # fallback: if cart is empty, choose the cheapest suitable item (even if it exceeds budget)
    if not cart:
        suitable_items = [i for i in restaurant.menu if matches_preferences(i, preferences)]
        if suitable_items:
            cheapest = min(suitable_items, key=lambda x: x.price)
            cart.append(cheapest)

    return cart


def place_order(restaurant: Restaurant, cart: List[MenuItem], address: str) -> Dict[str, Any]:
    """Return an order confirmation dictionary."""
    total_cost = sum(item.price for item in cart)
    estimated_delivery_minutes = 30 + len(cart) * 5

    return {
        "restaurant": restaurant.name,
        "items": [item.name for item in cart],
        "total_cost": round(total_cost, 2),
        "delivery_address": address,
        "estimated_delivery_time": f"{estimated_delivery_minutes} minutes",
        "confirmation_number": "ORDER-" + str(abs(hash((restaurant.name, address, total_cost))))[:8],
    }


if __name__ == "__main__":
    r1 = Restaurant(
        "Noodle House",
        [
            MenuItem("Spicy Ramen", 9.5, ["spicy", "noodles"]),
            MenuItem("Veggie Udon", 8.0, ["vegan", "noodles"]),
            MenuItem("Chicken Teriyaki", 11.0, ["protein", "rice"]),
        ],
        ["asian", "noodles"],
    )

    r2 = Restaurant(
        "Green Bites",
        [
            MenuItem("Kale Salad", 7.0, ["vegan", "gluten-free"]),
            MenuItem("Tofu Bowl", 10.0, ["vegan", "protein"]),
            MenuItem("Avocado Toast", 6.5, ["vegan"]),
        ],
        ["vegan", "salad"],
    )

    restaurants = [r1, r2]
    preferences = ["vegan", "spicy"]
    budget = 20.0

    chosen = choose_restaurant(restaurants, preferences)

    if chosen:
        cart = build_cart(chosen, preferences, budget)
        if cart:
            confirmation = place_order(chosen, cart, "123 Sauchiehall Street, Glasgow")
            print("Order placed!")
            print(confirmation)
        else:
            print("Cart is empty.")
    else:
        print("No suitable restaurant.")
# Out:
# Order placed!
# {'restaurant': 'Green Bites', 'items': ['Kale Salad', 'Tofu Bowl'], 'total_cost': 17.0, 'delivery_address': '123 Sauchiehall Street, Glasgow', 'estimated_delivery_time': '40 minutes', 'confirmation_number': 'ORDER-34737206'}

# %% [markdown]
# ## Example 2: Managing a To-Do List

# %%
# -----------------------------
# Example 2: Managing a to-do list (RUNNABLE VERSION)
# -----------------------------

from typing import List, Dict


class Task:
    def __init__(self, title: str, priority: str):
        """
        Suggested priority values: 'high' / 'medium' / 'low'
        """
        self.title = title
        self.priority = priority.lower().strip()
        self.completed = False

    def do(self) -> None:
        """
        Perform the task (simulated with a print statement).
        """
        print(f"Doing: {self.title} (priority: {self.priority})")
        self.completed = True


def group_by_priority(tasks: List[Task]) -> Dict[str, List[Task]]:
    """
    Group tasks by priority; create a new list when encountering a new priority.
    """
    priority_groups: Dict[str, List[Task]] = {}
    for task in tasks:
        p = task.priority
        if p not in priority_groups:
            priority_groups[p] = []
        priority_groups[p].append(task)
    return priority_groups


def run_tasks_in_order(priority_groups: Dict[str, List[Task]], order: List[str]) -> None:
    """
    Execute tasks following the given priority order, marking each as completed afterward.
    """
    for p in order:
        if p not in priority_groups:
            # Skip if there are no tasks for this priority
            continue
        for task in priority_groups[p]:
            task.do()
            print(f"Completed: {task.title}")


def all_completed(tasks: List[Task]) -> bool:
    """
    Return True if every task is completed.
    """
    return all(t.completed for t in tasks)


# --------- Sample data & demo run ----------
if __name__ == "__main__":
    # Build sample tasks
    tasks = [
        Task("Back up computer files", "high"),
        Task("Reply to emails", "medium"),
        Task("Tidy desk", "low"),
        Task("Submit assignment", "high"),
        Task("Plan weekly schedule", "medium"),
    ]

    # Group by priority
    priority_groups = group_by_priority(tasks)

    # Execute order: high -> medium -> low
    order = ["high", "medium", "low"]

    # Run tasks
    run_tasks_in_order(priority_groups, order)

    # Output result
    if all_completed(tasks):
        print("\nOUTPUT: All tasks completed ✅")
    else:
        print("\nOUTPUT: Some tasks are not completed ❌")
# Out:
# Doing: Back up computer files (priority: high)
# Completed: Back up computer files
# Doing: Submit assignment (priority: high)
# Completed: Submit assignment
# Doing: Reply to emails (priority: medium)
# Completed: Reply to emails
# Doing: Plan weekly schedule (priority: medium)
# Completed: Plan weekly schedule
# Doing: Tidy desk (priority: low)
# Completed: Tidy desk
#
# OUTPUT: All tasks completed ✅

# %% [markdown]
# Copilot provides corresponding Python implementations for the two examples I provided (a restaurant ordering system and a to-do list management system). Both programs use lists, dictionaries, and conditional statements (if/else), clearly converting the steps in the pseudocode into executable program structures, with the overall logic consistent with the original algorithm design.
# On initial execution, both programs encountered syntax or structural issues. In the restaurant ordering system program, the final output statement was incomplete, causing the program to fail to execute; in the to-do list program, the function definition was truncated and the final else block was missing, resulting in a SyntaxError. After submitting the error messages to Copilot, it correctly identified the source of the errors and provided suggested fixes.
# After correcting the errors, both programs run correctly on GitHub Codespaces. The restaurant ordering system can select restaurants based on user preferences and budget, create a shopping list, and output order confirmations; the to-do list program can execute tasks in high, medium, and low priority order and correctly mark task completion status.
# After discussing with classmates, we believe these two examples effectively demonstrate the process of converting algorithms and pseudocode into Python code. The food ordering system is closer to real-world applications but has a more complex structure; the to-do list example has simpler logic and is more suitable for beginners. This exercise also made us realize that while Copilot can provide effective code suggestions, manual testing and checking are still necessary.

# %% [markdown]
# YouTuBe

# %%
from IPython.display import *

# %%
from IPython.display import YouTubeVideo

YouTubeVideo("472AnCrHYVs")

# %% [markdown]
# ##Understanding a Program: Parsing and Reading
# This program integrates two libraries: `webbrowser` and `requests`. `webbrowser` opens websites in the browser, while `requests` sends requests to the network and retrieves data.
#
# The program uses six variables: `site`, `era`, `url`, `response`, `data`, and `old_site`. These variables store the user-entered website URL, date, the combined API link, and the processed data retrieved from the network, respectively.
#
# Ten strings appear throughout the program. These strings are primarily used to prompt the user for input, construct the query URL, and display relevant messages during program execution.
#
# The program uses `print()` four times. Initially, it prints a message; if the old website is successfully found, it prints the found URL and indicates that the browser will open soon; if the corresponding website version is not found, it prints an error message.
#
# Overall, this program demonstrates how to combine imported libraries, use variables and strings, and interact with the user through print(). It is a good example program for beginners to observe and understand basic concepts.

# %% [markdown]
# # Exploring Python: Finding Old Websites with the Internet Archive
#
# This notebook is used to practise basic Python programming concepts, including:
# - Importing libraries
# - Using variables
# - Taking user input
# - Making web requests
# - Handling errors with `try` / `except`
#
# The program below asks the user for a website URL and a date, then searches the
# Internet Archive (Wayback Machine) for the closest saved version of that website
# and opens it in a web browser.

# %%
import webbrowser
import requests

print("Shall we hunt down an old website?")

site = input("Type a website URL: ")
era = input("Type year, month, and date, e.g., 20150613: ")

url = "http://archive.org/wayback/available?url=%s&timestamp=%s" % (site, era)

response = requests.get(url)
data = response.json()

try:
    old_site = data["archived_snapshots"]["closest"]["url"]
    print("Found this copy:", old_site)
    print("It should appear in your browser.")
    webbrowser.open(old_site)
except:
    print("Sorry, could not find the site.")
# Out:
# Shall we hunt down an old website?
# Found this copy: http://web.archive.org/web/20160404000730/http://www.bbc.com/
# It should appear in your browser.

# %% [markdown]
# A webpage I selected will automatically pop up.
